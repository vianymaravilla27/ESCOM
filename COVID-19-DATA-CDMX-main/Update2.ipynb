# %% [markdown]
# <a href="https://colab.research.google.com/github/Vapss/COVID-19-DATA-CDMX/blob/main/Update2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # POSITIVOS CDMX

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from pandas import DataFrame


tasa = pd.read_csv("positivos.csv", usecols= ['tasa_positividad'])
tasa_cdmx = pd.read_csv("positivos.csv", usecols = ['tasa_positividad_cdmx'])

Data= pd.read_csv("positivos.csv", usecols =['fecha_toma_muestra','positivos_totales_cdmx','positivos_totales'] )



df = DataFrame(Data,columns=['fecha_toma_muestra','positivos_totales','positivos_totales_cdmx'])
df.plot(x = 'fecha_toma_muestra', y= 'positivos_totales_cdmx')

plt.show()

# %% [markdown]
# # POSITIVIDAD CDMX

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from pandas import DataFrame

tasa = pd.read_csv("positivos.csv", usecols= ['tasa_positividad'])
tasa_cdmx = pd.read_csv("positivos.csv", usecols = ['tasa_positividad_cdmx'])

Data= pd.read_csv("positivos.csv", usecols =['fecha_toma_muestra','tasa_positividad_cdmx','pruebas_totales'] )



df = DataFrame(Data,columns=['fecha_toma_muestra','pruebas_totales','tasa_positividad_cdmx'])
df.plot(x = 'fecha_toma_muestra', y= 'tasa_positividad_cdmx')

plt.show()

# %% [markdown]
# #Hospitalizaciones ZMVM

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from pandas import DataFrame

tasa = pd.read_csv("hospi.csv", usecols= ['hospitalizados_totales'])
tasa_cdmx = pd.read_csv("hospi.csv", usecols = ['hospitalizados_totales'])

Data= pd.read_csv("hospi.csv", usecols =['fecha','hospitalizados_totales'] )



df = DataFrame(Data,columns=['fecha','hospitalizados_totales'])
df.plot(x = 'fecha', y= 'hospitalizados_totales')

plt.show()
